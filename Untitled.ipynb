# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline
# Out:
# C:\Users\v-haabhi\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\v-haabhi\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\v-haabhi\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\v-haabhi\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data_table_out = pd.read_csv('Medicare_Provider_Charge_Outpatient_APC30_CY2011_v2.csv')

# %%
data_table_out.shape
# Out:
# (43372, 11)

# %%
data_table_out.head(10)
# Out:
#                                         APC  Provider Id  \
# 0  0012 - Level I Debridement & Destruction        10029
# 1  0012 - Level I Debridement & Destruction        20024
# 2  0012 - Level I Debridement & Destruction        30064
# 3  0012 - Level I Debridement & Destruction        30088
# 4  0012 - Level I Debridement & Destruction        30111
# 5  0012 - Level I Debridement & Destruction        40016
# 6  0012 - Level I Debridement & Destruction        40017
# 7  0012 - Level I Debridement & Destruction        40036
# 8  0012 - Level I Debridement & Destruction        40055
# 9  0012 - Level I Debridement & Destruction        40118
#
#                                        Provider Name  \
# 0                EAST ALABAMA MEDICAL CENTER AND SNF
# 1                 CENTRAL PENINSULA GENERAL HOSPITAL
# 2   UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# 3                      BANNER BAYWOOD MEDICAL CENTER
# 4  UNIVERSITY OF ARIZONA MEDICAL CTR- SOUTH CAM, THE
# ...

# %%
data_by_apc = data_table_out.groupby(['APC'])['Average  Estimated Submitted Charges'].agg(['sum', 'count', 'mean', 'std'])

# %%
data_by_apc['cof of var'] = data_by_apc['std']/data_by_apc['mean']

# %%
data_by_apc.sort_values(by='cof of var', ascending=False)
# Out:
#                                                              sum  count  \
# APC
# 0604 - Level 1 Hospital Clinic Visits               3.752231e+05   2210
# 0698 - Level II Eye Tests & Treatments              4.637526e+04    185
# 0019 - Level I Excision/ Biopsy                     1.007670e+06    445
# 0692 - Level II Electronic Analysis of Devices      3.223540e+05    457
# 0012 - Level I Debridement & Destruction            2.650556e+04    291
# 0013 - Level II Debridement & Destruction           3.883228e+05   1479
# 0690 - Level I Electronic Analysis of Devices       1.039427e+05    569
# 0204 - Level I Nerve Injections                     2.120603e+06   1657
# 0078 - Level III Pulmonary Treatment                1.368106e+06   2304
# 0020 - Level II Excision/ Biopsy                    3.636706e+06   1060
# 0608 - Level 5 Hospital Clinic Visits               2.904600e+05    640
# 0207 - Level III Nerve Injections                   5.159800e+06   2002
# ...

# %%
l1hcv_values = data_table_out[data_table_out['APC']=='0604 - Level 1 Hospital Clinic Visits']['Average  Estimated Submitted Charges'].values

# %%
sns.boxenplot(l1hcv_values)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
l2ett_values = data_table_out[data_table_out['APC']=='0698 - Level II Eye Tests & Treatments']['Average  Estimated Submitted Charges'].values

# %%
sns.boxplot(l2ett_values)

# %%
plt.style.use("C:\\Users\\v-haabhi\\Downloads\\scipy-japan-2019-master\\scipy-japan-2019-master\\elegant.mplstyle")

# %%
sns.boxplot(l2ett_values)

# %%
isns.boxenplot(l2ett_values)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
np.set_printoptions(formatter={'float': '{: 0.3f}'.format})

# %%
np.random.random(100)
# Out:
# array([ 0.915,  0.530,  0.264,  0.869,  0.838,  0.321,  0.226,  0.830,
#         0.866,  0.952,  0.611,  0.667,  0.627,  0.082,  0.300,  0.575,
#         0.274,  0.444,  0.653,  0.545,  0.900,  0.386,  0.583,  0.503,
#         0.818,  0.527,  0.425,  0.632,  0.133,  0.440,  0.310,  0.532,
#         0.960,  0.310,  0.372,  0.713,  0.547,  0.848,  0.389,  0.104,
#         0.335,  0.289,  0.915,  0.345,  0.060,  0.084,  0.305,  0.497,
#         0.042,  0.625,  0.796,  0.591,  0.717,  0.157,  0.649,  0.596,
#         0.132,  0.912,  0.551,  0.138,  0.067,  0.587,  0.803,  0.841,
#         0.109,  0.750,  0.493,  0.083,  0.422,  0.903,  0.694,  0.068,
#         0.406,  0.662,  0.361,  0.506,  0.755,  0.231,  0.726,  0.364,
#         0.932,  0.010,  0.971,  0.251,  0.672,  0.380,  0.822,  0.665,
#         0.429,  0.115,  0.755,  0.250,  0.110,  0.026,  0.567,  0.349,
#         0.659,  0.458,  0.668,  0.721])
